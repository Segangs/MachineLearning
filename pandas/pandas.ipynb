# %% [markdown]
# # 판다스 pandas

# %%
import numpy as np
import pandas as pd
from pygments.styles.paraiso_dark import AQUA

# %%
list1 = [1, 2, None, 4]
se = pd.Series(list1)
se
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# dtype: float64

# %%
print(type(se))  # 클래스로 나옴
print(se.isna())  # bool
# Out:
# <class 'pandas.Series'>
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
for item in se:
    if item == True:
        print("찾았다. 없는 값을")
# Out:
# 찾았다. 없는 값을

# %%
print(se)
print(se[0])  # 1.0
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# dtype: float64
# 1.0

# %%
se = pd.Series(list1, index=['A', 'B', 'C', 'D'])
print(se)
# Out:
# A    1.0
# B    2.0
# C    NaN
# D    4.0
# dtype: float64

# %%
month_se = pd.Series(['1월', '2월', '3월', '4월'])
income_se = pd.Series([9500, 6200, 6050, 7000])
expenses_se = pd.Series([5040, 2350, 2300, 4800])
df = pd.DataFrame({'월': month_se, '수입': income_se, '지출': expenses_se})
print(df['월'])
print(df['수입'][0])
# Out:
# 0    1월
# 1    2월
# 2    3월
# 3    4월
# Name: 월, dtype: str
# 9500

# %%
(df.columns)[0]
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
np.argmax(df['수입'])
np.int64(3)
df['수입'][3]

income_se.max()
income_se.min()
income_se.mean()
# Out:
# np.float64(7187.5)

# %%
print(f"동운이네 상점의 수입 합계 :",income_se.sum())
print(f"동운이네 상점의 지출 합계 :",expenses_se.sum())
# Out:
# 동운이네 상점의 수입 합계 : 28750
# 동운이네 상점의 지출 합계 : 14490

# %%
df = pd.read_csv("./csv/vehicle_prod.csv")
print(df)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62
# 5     Mexico   2.01   2.05   1.50   2.25   2.54
