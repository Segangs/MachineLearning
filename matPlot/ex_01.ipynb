# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4], [1,2,3,4])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x = np.arange(-10, 11)
y = np.square(x)

plt.plot(x,y)
plt.show()
